# %%
import pandas as pd

# %%
import numpy as np

# %%
building=pd.read_csv('building_inventory_021020-2.csv')
# Out:
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_62911/3689352032.py:1: DtypeWarning: Columns (1,40,44,47,51,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   building=pd.read_csv('building_inventory_021020-2.csv')

# %%
building
# Out:
#           id    pid_long         cm_id       building_typology  \
# 0      88905         NaN           NaN                     NaN
# 1      51137  1600083000           NaN           Single-Family
# 2      18045   202560000           NaN           Single-Family
# 3      94001  2200577000           NaN     Convention/Assembly
# 4      92940  1600058000           NaN                     NaN
# ...      ...         ...           ...                     ...
# 98925  66236  1001363000  1.001363e+09  Multi-Family (2 units)
# 98926  68980  2007422000           NaN           Single-Family
# 98927  95554  2203167050           NaN           Single-Family
# 98928  58753   200894010  2.008940e+08  Multi-Family (2 units)
# 98929   6205  1902142000           NaN           Single-Family
#
#                        building_subtypology              use_class  \
# 0                                       NaN                    NaN
# 1                  Single-Family, 1915-1949            Residential
# ...

# %%
parkinglot=pd.read_csv('Snow_Emergency_Parking_Lots.csv',encoding = 'latin1')

# %%
parkinglot
# Out:
#               X            Y  ObjectId  \
# 0  -7918411.415  5213945.934         1
# 1  -7920693.465  5213501.578         2
# 2  -7917331.616  5215700.967         3
# 3  -7921071.951  5203873.964         4
# 4  -7920838.180  5203887.506         5
# 5  -7910585.655  5214060.415         6
# 6  -7908860.203  5211509.010         7
# 7  -7907958.515  5211427.690         8
# 8  -7907680.216  5212805.713         9
# 9  -7913402.038  5211611.415        10
# 10 -7913223.927  5212108.393        11
# 11 -7913235.059  5213115.984        12
# 12 -7909350.008  5217566.329        13
# 13 -7911698.850  5204727.182        14
# 14 -7910953.009  5208746.015        15
# 15 -7910429.808  5206385.684        16
# 16 -7911153.384  5208755.048        17
# 17 -7911042.065  5208759.564        18
# 18 -7913001.288  5207410.730        19
# 19 -7911142.252  5207044.952        20
# 20 -7911665.454  5204456.310        21
# 21 -7912110.732  5209717.112        22
# 22 -7907824.931  5217228.789        23
# ...

# %%
hotel=building.loc[building['building_typology'] == 'Hotel']

# %%
hotel
# Out:
#           id   pid_long  cm_id building_typology building_subtypology  \
# 199    43735  602680100    NaN             Hotel  Hotel, 1980-present
# 205    97181  303883000    NaN             Hotel  Hotel, 1980-present
# 218    95854  602674165    NaN             Hotel  Hotel, 1980-present
# 231    95368  305648000    NaN             Hotel  Hotel, 1980-present
# 241    94957  100549001    NaN             Hotel     Hotel, 1950-1979
# ...      ...        ...    ...               ...                  ...
# 96979  64647  303295000    NaN             Hotel     Hotel, 1915-1949
# 97706  46935  401328000    NaN             Hotel                  NaN
# 98001  43592  401117000    NaN             Hotel      Hotel, Pre-1915
# 98016  38416  500087000    NaN             Hotel      Hotel, Pre-1915
# 98373  30431  304810010    NaN             Hotel     Hotel, 1915-1949
#
#         use_class          sqft_class year_built_class     st_num  \
# ...

# %%
from sklearn.neighbors import DistanceMetric

# %%
from math import radians

# %%
from geopy import distance

# %%
import sys

# %%
from math import dist

# %%
pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas

# %%
import geopy

# %%
from geopy.geocoders import Nominatim

# %%
from geopy.extra.rate_limiter import RateLimiter

# %%
geolocator=Nominatim(user_agent='my_request')

# %%
geocode=RateLimiter(geolocator.geocode,min_delay_seconds=1)

# %%
hotel['address'] = hotel['st_num'] + ' ' + hotel['st_name'] + ' ' + hotel['st_name_suf'] + ' BOSTON'
# Out:
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_62911/2759424091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel['address'] = hotel['st_num'] + ' ' + hotel['st_name'] + ' ' + hotel['st_name_suf'] + ' BOSTON'

# %%
hotel['address']
# Out:
# 199                   606 CONGRESS ST BOSTON
# 205             56 - 68 DEVONSHIRE ST BOSTON
# 218                     660 SUMMER ST BOSTON
# 231              240 - 242 TREMONT ST BOSTON
# 241             225 WM F MCCLELLAN HW BOSTON
#                         ...
# 96979              247 243 HANOVER ST BOSTON
# 97706              30 24 BELVIDERE ST BOSTON
# 98001                   350 STUART ST BOSTON
# 98016    76 82 CHARLES STREET SOUTH   BOSTON
# 98373               505 WASHINGTON ST BOSTON
# Name: address, Length: 83, dtype: object

# %%
hotel['geolocation']=hotel['address'].apply(geocode)

# %%
hotel['geolocation']
# Out:
# 199      (Capiz Bar & Lounge, 606, Congress Street, Sea...
# 205      (Devonshire Street, Church Green, Downtown Bos...
# 218      (660, Summer Street, Seaport, South Boston, Bo...
# 231      (Tremont Street, Roxbury Crossing, Roxbury, Bo...
# 241                                                   None
#                                ...
# 96979                                                 None
# 97706    (Belvidere Street, Fenway / Kenmore, Boston, S...
# 98001    (350, Stuart Street, Bay Village, Back Bay, Bo...
# 98016    (Charles Street South, Bay Village, Boston, Su...
# 98373    (The Godfrey Hotel Boston, 505, Washington Str...
# Name: geolocation, Length: 83, dtype: object

# %%
hotel['Longitude']=hotel['geolocation'].apply(lambda x: x.longitude if x else None)
# Out:
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_58475/1223207761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel['Longitude']=hotel['geolocation'].apply(lambda x: x.longitude if x else None)

# %%
hotel['Longitude']
# Out:
# 199     -71.039623
# 205     -71.057957
# 218     -71.037938
# 231     -71.092329
# 241            NaN
#            ...
# 96979          NaN
# 97706   -71.082670
# 98001   -71.072837
# 98016   -71.067049
# 98373   -71.061488
# Name: Longitude, Length: 83, dtype: float64

# %%
hotel['Latitude']=hotel['geolocation'].apply(lambda x: x.latitude if x else None)
# Out:
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_58475/3172981060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel['Latitude']=hotel['geolocation'].apply(lambda x: x.latitude if x else None)

# %%
hotel['Latitude']
# Out:
# 199      42.347952
# 205      42.353783
# 218      42.345525
# 231      42.332874
# 241            NaN
#            ...
# 96979          NaN
# 97706    42.345785
# 98001    42.349282
# 98016    42.351394
# 98373    42.354732
# Name: Latitude, Length: 83, dtype: float64

# %%
hotelsubset=hotel[['id','address','geolocation','Longitude','Latitude']]

# %%
hotelsubset
# Out:
#           id                              address  \
# 199    43735               606 CONGRESS ST BOSTON
# 205    97181         56 - 68 DEVONSHIRE ST BOSTON
# 218    95854                 660 SUMMER ST BOSTON
# 231    95368          240 - 242 TREMONT ST BOSTON
# 241    94957         225 WM F MCCLELLAN HW BOSTON
# ...      ...                                  ...
# 96979  64647            247 243 HANOVER ST BOSTON
# 97706  46935            30 24 BELVIDERE ST BOSTON
# 98001  43592                 350 STUART ST BOSTON
# 98016  38416  76 82 CHARLES STREET SOUTH   BOSTON
# 98373  30431             505 WASHINGTON ST BOSTON
#
#                                              geolocation  Longitude   Latitude
# 199    (Capiz Bar & Lounge, 606, Congress Street, Sea... -71.039623  42.347952
# 205    (Devonshire Street, Church Green, Downtown Bos... -71.057957  42.353783
# 218    (660, Summer Street, Seaport, South Boston, Bo... -71.037938  42.345525
# ...

# %%
hotelcoordinates=hotel[['id','Longitude','Latitude']]

# %%
hotel_dict = hotelcoordinates.set_index('id').T.to_dict('list')

# %%
hotel_dict
# Out:
# {43735: [-71.0396228, 42.3479524],
#  97181: [-71.0579568, 42.3537832],
#  95854: [-71.03793848361921, 42.3455247],
#  95368: [-71.0923294, 42.3328739],
#  94957: [nan, nan],
#  94650: [-71.11815850541063, 42.3602992],
#  61672: [-71.0550616, 42.3415431],
#  79037: [-71.08386718567789, 42.34651075],
#  96207: [-71.06135479193117, 42.36420135],
#  885: [-71.0607367, 42.3574423],
#  53226: [-71.0809307, 42.3457259],
#  89133: [-71.0918678, 42.346683],
#  6231: [-71.07158468201447, 42.35282695],
#  18389: [-71.0532751, 42.3569494],
#  51992: [-71.06660593534323, 42.361730300000005],
#  77755: [-71.0851371719761, 42.346413600000005],
#  24500: [-71.0575622, 42.3562592],
#  55413: [-71.0923294, 42.3328739],
#  18402: [-71.0580153, 42.3590373],
#  16257: [-71.06009626933417, 42.35751105],
#  32596: [-71.0482063, 42.3203832],
#  94652: [nan, nan],
#  52535: [-71.06042190217188, 42.3265574],
#  92675: [-71.0621241, 42.3439263],
#  56260: [-71.06052720390605, 42.3706247],
# ...

# %%
parkinglotcoordinates=parkinglot[['ObjectId','Longitude','Latitude']]

# %%
parkinglotcoordinates
# Out:
#     ObjectId  Longitude  Latitude
# 0          1   -71.1323  42.35261
# 1          2   -71.1528  42.34966
# 2          3   -71.1226  42.36426
# 3          4   -71.1562  42.28571
# 4          5   -71.1541  42.28580
# 5          6   -71.0620  42.35337
# 6          7   -71.0465  42.33643
# 7          8   -71.0384  42.33589
# 8          9   -71.0359  42.34504
# 9         10   -71.0873  42.33711
# 10        11   -71.0857  42.34041
# 11        12   -71.0858  42.34710
# 12        13   -71.0509  42.37664
# 13        14   -71.0720  42.29138
# 14        15   -71.0653  42.31808
# 15        16   -71.0606  42.30240
# 16        17   -71.0671  42.31814
# 17        18   -71.0661  42.31817
# 18        19   -71.0837  42.30921
# 19        20   -71.0670  42.30678
# 20        21   -71.0717  42.28958
# 21        22   -71.0757  42.32453
# 22        23   -71.0372  42.37440
# 23        24   -71.0376  42.37487
# 24        25   -71.0377  42.37558
# 25        26   -71.1251  42.25519
# ...

# %%
parkinglot_dict = parkinglotcoordinates.set_index('ObjectId').T.to_dict('list')

# %%
parkinglot_dict
# Out:
# {1: [-71.1323, 42.35261],
#  2: [-71.1528, 42.34966],
#  3: [-71.1226, 42.36426],
#  4: [-71.1562, 42.28571],
#  5: [-71.1541, 42.2858],
#  6: [-71.062, 42.35337],
#  7: [-71.0465, 42.33643],
#  8: [-71.0384, 42.33589],
#  9: [-71.0359, 42.34504],
#  10: [-71.0873, 42.33711],
#  11: [-71.0857, 42.34041],
#  12: [-71.0858, 42.3471],
#  13: [-71.0509, 42.37664],
#  14: [-71.072, 42.29138],
#  15: [-71.0653, 42.31808],
#  16: [-71.0606, 42.3024],
#  17: [-71.0671, 42.31814],
#  18: [-71.0661, 42.31817],
#  19: [-71.0837, 42.30921],
#  20: [-71.067, 42.30678],
#  21: [-71.0717, 42.28958],
#  22: [-71.0757, 42.32453],
#  23: [-71.0372, 42.3744],
#  24: [-71.0376, 42.37487],
#  25: [-71.0377, 42.37558],
#  26: [-71.1251, 42.25519],
#  27: [-71.1235, 42.25654],
#  28: [-71.0973, 42.31655],
#  29: [-71.1151, 42.31108],
#  30: [-71.1073, 42.32225],
#  31: [-71.0988, 42.31565],
#  32: [-71.1124, 42.31808],
#  33: [-71.0927, 42.26873],
#  34: [-71.0954, 42.26876],
#  35: [-71.1287, 42.2875],
# ...

# %%
for [x,y] in hotel_dict.values():
    min_distance=sys.maxsize
    for [p,q] in parkinglot_dict.values():
        res = dist([x,y], [p,q])
        if res < min_distance:
            min_distance = res
            key1 = {i for i in parkinglot_dict if parkinglot_dict[i]==[p,q]}
            hotelsubset['XCOORD'] = p
            hotelsubset['YCOORD'] = q
            hotelsubset['Minimum Distance'] = min_distance
    key2 = {i for i in hotel_dict if hotel_dict[i]==[x,y]}
# Out:
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_58475/1966618565.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotelsubset['XCOORD'] = p
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_58475/1966618565.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotelsubset['YCOORD'] = q
# /var/folders/tg/rgm7sv090r13fdl9nwkrfc9w0000gn/T/ipykernel_58475/1966618565.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
hotelsubset
# Out:
#           id                              address  \
# 199    43735               606 CONGRESS ST BOSTON
# 205    97181         56 - 68 DEVONSHIRE ST BOSTON
# 218    95854                 660 SUMMER ST BOSTON
# 231    95368          240 - 242 TREMONT ST BOSTON
# 241    94957         225 WM F MCCLELLAN HW BOSTON
# ...      ...                                  ...
# 96979  64647            247 243 HANOVER ST BOSTON
# 97706  46935            30 24 BELVIDERE ST BOSTON
# 98001  43592                 350 STUART ST BOSTON
# 98016  38416  76 82 CHARLES STREET SOUTH   BOSTON
# 98373  30431             505 WASHINGTON ST BOSTON
#
#                                              geolocation  Longitude  \
# 199    (Capiz Bar & Lounge, 606, Congress Street, Sea... -71.039623
# 205    (Devonshire Street, Church Green, Downtown Bos... -71.057957
# 218    (660, Summer Street, Seaport, South Boston, Bo... -71.037938
# 231    (Tremont Street, Roxbury Crossing, Roxbury, Bo... -71.092329
# ...
